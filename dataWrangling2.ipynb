# %% [markdown]
# <a href="https://colab.research.google.com/github/shruti24101729/Data-Analysis-and-Visualization/blob/main/dataWrangling2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#data wrangling---gathering,assessing, cleaning data
#also called data munging
#types of unclean data:
#-dirty data(data with quality issue),low quality data --duplicated , missing,corrupted,inaccurate
#-messy data -untidy data, has structural issues
# -tidy data each variable forms a column,each observation forms a row,each observational unit forms a table

# %%
import pandas as pd
import numpy as np

# %%
patients=pd.read_csv('patients.csv')
treatments=pd.read_csv('treatments.csv')
adverse_reactions=pd.read_csv('adverse_reactions.csv')
treatments_cut=pd.read_csv('treatments_cut.csv')

# %%
patients.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state  zip_code        country  \
# 0  Rancho California  California   92390.0  United States
# 1          Armstrong    Illinois   61812.0  United States
# 2               York    Nebraska   68467.0  United States
# 3         Woodbridge          NJ    7095.0  United States
# 4             Dothan          AL   36303.0  United States
#
#                                       contact  birthdate  weight  height   bmi
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66  19.6
# ...

# %%
treatments.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0           NaN
# 1          0.97
# 2           NaN
# 3          0.35
# 4          0.32

# %%
treatments_cut.head()
# Out:
#   given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0      jožka  resanovič  22u - 30u          -         7.56       7.22
# 1  inunnguaq   heilmann  57u - 67u          -         7.85       7.45
# 2      alwin   svensson  36u - 39u          -         7.78       7.34
# 3        thể      lương          -  61u - 64u         7.64       7.22
# 4     amanda    ribeiro  36u - 44u          -         7.85       7.47
#
#    hba1c_change
# 0          0.34
# 1           NaN
# 2           NaN
# 3          0.92
# 4          0.38

# %%
adverse_reactions.head()
# Out:
#   given_name     surname           adverse_reaction
# 0      berta  napolitani  injection site discomfort
# 1       lena        baer               hypoglycemia
# 2     joseph         day               hypoglycemia
# 3     flavia  fiorentino                      cough
# 4    manouck     wubbels          throat irritation

# %%
#step1 always write summary
#step2 always write column description
#step 3 add any additional information
#always read data manually first thoroughly, lots of problem will get solved
#step4 assessment:describe(),info(),sample(),head and tail,isnull,duplicated

# %%
#dataframes to excel
with pd.ExcelWriter('all_data.xlsx') as writer:
    patients.to_excel(writer,sheet_name='patients',index=False)
    treatments.to_excel(writer,sheet_name='treatments',index=False)
    adverse_reactions.to_excel(writer,sheet_name='adverse_reactions',index=False)
    treatments_cut.to_excel(writer,sheet_name='treatments_cut',index=False)

# %%
patients.sample(4)## do several times to include information
# Out:
#      patient_id assigned_sex given_name   surname                     address  \
# 88           89         male     Marius    Hansen       3251 Radio Park Drive
# 1             2       female     Pamela      Hill   2370 University Hill Road
# 191         192       female    Fanette  Fournier        602 Tator Patch Road
# 445         446         male    Maximus    Henzen  4334 Black Oak Hollow Road
#
#           city       state  zip_code        country  \
# 88     Augusta          GA   30902.0  United States
# 1    Armstrong    Illinois   61812.0  United States
# 191    Chicago    Illinois   60607.0  United States
# 445   San Jose  California   95113.0  United States
#
#                                          contact   birthdate  weight  height  \
# 88          706-755-5723MariusHansen@teleworm.us   6/27/1948   227.7      76
# 1          PamelaSHill@cuvox.de+1 (217) 569-3204    4/3/1967   118.8      66
# 191  FanetteFournier@einrot.com+1 (312) 864-5737  10/24/1938   112.6      60
# ...

# %%
patients.info()

#giving null values of few columns
#look for appropriate dataType
#assignedsex-category,birth-datetime,zipcode-string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       491 non-null    object
#  5   city          491 non-null    object
#  6   state         491 non-null    object
#  7   zip_code      491 non-null    float64
#  8   country       491 non-null    object
#  9   contact       491 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 55.1+ KB

# %%
patients[patients['address'].isnull()]

#giving information of quality issue
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %%
treatments.info(),treatments_cut.info()
#hba1c_change has missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  171 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    70 non-null     object
#  1   surname       70 non-null     object
#  2   auralin       70 non-null     object
#  3   novodra       70 non-null     object
#  4   hba1c_start   70 non-null     float64
# ...

# %%
adverse_reactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   given_name        34 non-null     object
#  1   surname           34 non-null     object
#  2   adverse_reaction  34 non-null     object
# dtypes: object(3)
# memory usage: 944.0+ bytes

# %%
#check for duplicity
patients.duplicated().sum(),treatments.duplicated().sum(),adverse_reactions.duplicated().sum()
# Out:
# (0, 1, 0)

# %%
patients['patient_id'].nunique()
# Out:
# 503

# %%
patients.duplicated(subset=['given_name','surname']).sum()
# Out:
# 5

# %%
patients[patients.duplicated(subset=['given_name','surname'])]

#duplicate entries by the name of john doe
# Out:
#      patient_id assigned_sex given_name surname          address      city  \
# 229         230         male       John     Doe  123 Main Street  New York
# 237         238         male       John     Doe  123 Main Street  New York
# 244         245         male       John     Doe  123 Main Street  New York
# 251         252         male       John     Doe  123 Main Street  New York
# 277         278         male       John     Doe  123 Main Street  New York
#
#     state  zip_code        country                      contact birthdate  \
# 229    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 237    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 244    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 251    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 277    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
#
#      weight  height   bmi
# 229   180.0      72  24.4
# ...

# %%
treatments[treatments.duplicated()]

#one duplicate entry by the name joesph day
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
treatments[treatments.duplicated(subset=['given_name','surname'])]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
treatments_cut[treatments_cut.duplicated()]
# Out:
# Empty DataFrame
# Columns: [given_name, surname, auralin, novodra, hba1c_start, hba1c_end, hba1c_change]
# Index: []

# %%
adverse_reactions[adverse_reactions.duplicated()]
# Out:
# Empty DataFrame
# Columns: [given_name, surname, adverse_reaction]
# Index: []

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
patients[patients['weight']==48.8]

#impossible
# Out:
#      patient_id assigned_sex given_name   surname              address  \
# 210         211       female    Camilla  Zaitseva  4689 Briarhill Lane
#
#         city state  zip_code        country  \
# 210  Wooster    OH   44691.0  United States
#
#                                        contact   birthdate  weight  height  \
# 210  330-202-2145CamillaZaitseva@superrito.com  11/26/1938    48.8      63
#
#       bmi
# 210  19.1

# %%
height_err=patients.query('height==27')
height_err
#impossible
# Out:
#    patient_id assigned_sex given_name  surname               address    city  \
# 4           5         male        Tim  Neudorf  1428 Turkey Pen Lane  Dothan
#
#   state  zip_code        country                          contact  birthdate  \
# 4    AL   36303.0  United States  334-515-7487TimNeudorf@cuvox.de  2/18/1928
#
#    weight  height   bmi
# 4   192.3      27  26.1

# %%
#make a single dataframe of treatments,treatment_cuts and adverse reactions

treatments.describe()
# Out:
#        hba1c_start   hba1c_end  hba1c_change
# count   280.000000  280.000000    171.000000
# mean      7.985929    7.589286      0.546023
# std       0.568638    0.569672      0.279555
# min       7.500000    7.010000      0.200000
# 25%       7.660000    7.270000      0.340000
# 50%       7.800000    7.420000      0.380000
# 75%       7.970000    7.570000      0.920000
# max       9.950000    9.580000      0.990000

# %%
hba1c_change=treatments.hba1c_change.unique()
hba1c_change
treatments.sort_values('hba1c_change',na_position='first')
#hba1c_change has wrong values
# Out:
#     given_name      surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0     veronika     jindrová  41u - 48u          -         7.63       7.20
# 2     yukitaka     takenaka          -  39u - 36u         7.68       7.25
# 8        saber       ménard          -  54u - 54u         8.08       7.70
# 9         asia      woźniak  30u - 36u          -         7.76       7.37
# 10      joseph          day  29u - 36u          -         7.70       7.19
# ..         ...          ...        ...        ...          ...        ...
# 49     jackson      addison          -  42u - 42u         7.99       7.51
# 17        gina         cain          -  36u - 36u         7.88       7.40
# 32       laura  ehrlichmann          -  43u - 40u         7.95       7.46
# 245         wu         sung          -  47u - 48u         7.61       7.12
# 138    giovana        rocha          -  23u - 21u         7.87       7.38
#
#      hba1c_change
# 0             NaN
# 2             NaN
# 8             NaN
# ...

# %%
#assessing data is an iterative process
#Data Quality Dimensions
#Completeness(missing values),validity(e.g height is negative,not possible),accuracy(weight 1kg not possible for any adult,possible but not logical)
#,consistency(New York ,NY )
#order of severity completeness<-validity<-accuracy<-consistency

# %%
#Data Cleaning
#1.Quality-completeness
#2.Tidiness
#3.Quality-validity
#4.Quality-accuracy
#5.Quality-consistency
#alaways make sure to create a copy of your pandas dataframe before you start the cleaning proccess

# %%
patients_copy=patients.copy()
treatments_copy=treatments.copy()
adverse_reactions_copy=adverse_reactions.copy()
treatments_cut_copy=treatments_cut.copy()

# %%
##completeness

patients_copy.fillna('no data',inplace=True)
#replaced nan values of patients dataframe with no data
# Out:
# <ipython-input-31-ca94cc6dcf49>:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'no data' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   patients_copy.fillna('no data',inplace=True)

# %%
patients_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       503 non-null    object
#  5   city          503 non-null    object
#  6   state         503 non-null    object
#  7   zip_code      503 non-null    object
#  8   country       503 non-null    object
#  9   contact       503 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 55.1+ KB

# %%
treatments_copy.head()
#subtracting hba1c_start to hba1c_end to get hba1c_change
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0           NaN
# 1          0.97
# 2           NaN
# 3          0.35
# 4          0.32

# %%
treatments_copy['hba1c_change']=treatments_copy['hba1c_start']-treatments_copy['hba1c_end']
treatments_cut_copy['hba1c_change']=treatments_cut_copy['hba1c_start']-treatments_cut_copy['hba1c_end']

# %%
treatments_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   given_name    280 non-null    object
#  1   surname       280 non-null    object
#  2   auralin       280 non-null    object
#  3   novodra       280 non-null    object
#  4   hba1c_start   280 non-null    float64
#  5   hba1c_end     280 non-null    float64
#  6   hba1c_change  280 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 15.4+ KB

# %%
#tidiness
patients_copy.head()
#contact should be broken into phone and email ,use regex
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state zip_code        country  \
# 0  Rancho California  California  92390.0  United States
# 1          Armstrong    Illinois  61812.0  United States
# 2               York    Nebraska  68467.0  United States
# 3         Woodbridge          NJ   7095.0  United States
# 4             Dothan          AL  36303.0  United States
#
#                                       contact  birthdate  weight  height   bmi
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66  19.6
# ...

# %%
import re#regex
def find_contact_details(text,str)->tuple:
  if pd.isna(text):
    return np.nan

  # creating the phone number pattern
  phone_number_pattern=re.compile(r"(\+[\d]{1,3}\s)?(\(?[\d]{3}\)?\s?-?[\d]{3}\s?-?[\d]{3}\s?-?[\d]{4})")
  phone_number=re.findall(phone_number_pattern,text)

  if len(phone_number)<=0:
    phone_number=np.nan
  elif len(phone_number)>=2:
    phone_number=phone_number[1]
  else:
    phone_number=phone_number[0]

  possible_email_add=re.sub(phone_number_pattern,"",text).strip()

  return phone_number[-1],possible_email_add

# %%
df=patients_copy.copy()
#f['contact'].apply(lambda x:find_contact_details(x))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-6fbeb5f833da> in <cell line: 2>()
#       1 df=patients_copy.copy()
# ----> 2 df['contact'].apply(lambda x:find_contact_details(x))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
# ...

# %%
treatments_df=pd.concat([treatments,treatments_cut])

# %%
treatments_df=treatments_df.melt(id_vars=['given_name','surname','hba1c_start','hba1c_end','hba1c_change'],var_name='type',value_name='dose')

# %%
treatments_df[treatments_df['dose']!='-'].reset_index(drop=True)
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20           NaN  auralin
# 1           skye  gormanston         7.97       7.62          0.35  auralin
# 2         sophia      haugen         7.65       7.27          0.38  auralin
# 3          eddie      archer         7.89       7.55          0.34  auralin
# 4           asia     woźniak         7.76       7.37           NaN  auralin
# ..           ...         ...          ...        ...           ...      ...
# 345  christopher    woodward         7.51       7.06          0.95  novodra
# 346        maret    sultygov         7.67       7.30           NaN  novodra
# 347        lixue       hsueh         9.21       8.80          0.91  novodra
# 348        jakob    jakobsen         7.96       7.51          0.95  novodra
# 349        berta  napolitani         7.68       7.21           NaN  novodra
#
#           dose
# 0    41u - 48u
# 1    33u - 36u
# ...

# %%
treatments_df['dose'].str.split('-')
# Out:
# 0      41u
# 1
# 2
# 3      33u
# 4
#        ...
# 695
# 696    28u
# 697
# 698    42u
# 699
# Name: dose, Length: 700, dtype: object

# %%
treatments_df['dose_start'],treatments_df['dose_end']=treatments_df['dose'].str.split('-').str.get(0),treatments_df['dose'].str.split('-').str.get(1)

# %%
treatments_df.drop(columns=['dose'],inplace=True)

# %%
treatments_df['dose_start']=treatments_df['dose_start'].str.replace('u','')
treatments_df['dose_end']=treatments_df['dose_end'].str.replace('u','')

# %%
treatments_df
# Out:
#     given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0     veronika    jindrová         7.63       7.20           NaN  auralin
# 1       elliot  richardson         7.56       7.09          0.97  auralin
# 2     yukitaka    takenaka         7.68       7.25           NaN  auralin
# 3         skye  gormanston         7.97       7.62          0.35  auralin
# 4       alissa      montez         7.78       7.46          0.32  auralin
# ..         ...         ...          ...        ...           ...      ...
# 695     rovzan     kishiev         7.75       7.41          0.34  novodra
# 696      jakob    jakobsen         7.96       7.51          0.95  novodra
# 697      bernd   schneider         7.74       7.44          0.30  novodra
# 698      berta  napolitani         7.68       7.21           NaN  novodra
# 699     armina       sauvé         7.86       7.40           NaN  novodra
#
#     dose_start dose_end
# 0           41       48
# 1
# 2
# ...

# %%
treatments_df.merge(adverse_reactions,on=['given_name','surname'],how='left')
# Out:
#     given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0     veronika    jindrová         7.63       7.20           NaN  auralin
# 1       elliot  richardson         7.56       7.09          0.97  auralin
# 2     yukitaka    takenaka         7.68       7.25           NaN  auralin
# 3         skye  gormanston         7.97       7.62          0.35  auralin
# 4       alissa      montez         7.78       7.46          0.32  auralin
# ..         ...         ...          ...        ...           ...      ...
# 695     rovzan     kishiev         7.75       7.41          0.34  novodra
# 696      jakob    jakobsen         7.96       7.51          0.95  novodra
# 697      bernd   schneider         7.74       7.44          0.30  novodra
# 698      berta  napolitani         7.68       7.21           NaN  novodra
# 699     armina       sauvé         7.86       7.40           NaN  novodra
#
#     dose_start dose_end           adverse_reaction
# ...
